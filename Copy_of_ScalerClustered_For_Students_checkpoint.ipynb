# %%
import pandas as pd

# %%
df=pd.read_csv('scaler_hashed_for_students.csv')

# %%
import re
def remove_special (string):
    new_string=re.sub('[^A-Za-z ]+', '', string)
    return new_string

# %%
#what happens here
mystring='\tAirtel\\\\&&**() X Labs'
re.sub('[^A-Za-z ]+', '', mystring)
# Out:
# 'Airtel X Labs'

# %%
pd.set_option('display.max_rows', 1000)

# %%
df
#sde, sde 2
# Out:
#         Unnamed: 0               company_hash  \
# 0                0             czniswwz sucsk
# 1                1  oznskulz subilihh nshswzc
# 2                2              faulwklwsl ks
# 3                3                  wirijzcsk
# 4                4                 osbw toidj
# ...            ...                        ...
# 205838      206918                  kjjnz sul
# 205839      206919                  djtokclih
# 205840      206920                   kllinswz
# 205841      206921             uiw kjjnslkgnz
# 205842      206922             hiotku fwkunza
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 205838  70027b728c8ee901fe979533ed94ffda97be08fc23f33b...   2008.0   220000
# 205839  7f7292ffad724ebbe9ca860f515245368d714c84705b42...   2017.0   500000
# 205840  cb25cc7304e9a24facda7f5567c7922ffc48e3d5d6018c...   2021.0   700000
# 205841  fb46a1a2752f5f652ce634f6178d0578ef6995ee59f6c8...   2019.0  5100000
# 205842  0bcfc1d05f2e8dc4147743a1313aa70a119b41b30d4a1f...   2014.0  1240000
#
#               job_position  ctc_updated_year
# 0                    Other            2020.0
# 1       FullStack Engineer            2019.0
# 2         Backend Engineer            2020.0
# 3         Backend Engineer            2019.0
# 4       FullStack Engineer            2019.0
# ...                    ...               ...
# 205838                 NaN            2019.0
# 205839                 NaN            2020.0
# 205840                 NaN            2021.0
# 205841                 NaN            2019.0
# 205842                 NaN            2016.0
#
# [205843 rows x 7 columns]

# %%
pd.DataFrame(df.job_position.value_counts())[50:60]
# Out:
#                                 job_position
# Technology Analyst                        10
# SDE 3                                     10
# Senior Consultant                          9
# SDE-1                                      9
# Software Engineer (Full stack)             9
# Software Engineer I                        8
# Senior Engineer                            8
# Senior Systems Engineer                    8
# Associate  software  engineer              8
# SDE2                                       8

# %% [markdown]
# # Data Preprocessing - Cleaning of all variables

# %%
df.drop(columns=['email_hash','Unnamed: 0'],inplace=True)
#dropping email will create different records and there will be no confusion for clustering

# %%
df.job_position=df.job_position.apply(lambda x: remove_special(str(x)))
df.job_position=df.job_position.apply(lambda x: x.lower())
df.job_position=df.job_position.apply(lambda x: x.strip())
df.job_position
# Out:
# 0                      other
# 1         fullstack engineer
# 2           backend engineer
# 3           backend engineer
# 4         fullstack engineer
#                  ...
# 205838                   nan
# 205839                   nan
# 205840                   nan
# 205841                   nan
# 205842                   nan
# Name: job_position, Length: 205843, dtype: object

# %%
df.shape
# Out:
# (205843, 5)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (188247, 5)

# %%
df['company_hash'].value_counts().sort_index()
# Out:
# 0                                 2
# 0000                              1
# 01 fauzota                        2
# 05gu bsuezknwe josvkwz nshswzc    2
# 1                                 2
#                                  ..
# zzhjekfaf nwc                     1
# zzhzqz fibw wzle                  1
# zzm wzleuinitszf                  3
# zzqansbz sul                      1
# zzqaukdrkos                       1
# Name: company_hash, Length: 37299, dtype: int64

# %%
df.company_hash=df.company_hash.apply(lambda x: remove_special(str(x)))
df.company_hash=df.company_hash.apply(lambda x: x.lower())
df.company_hash=df.company_hash.apply(lambda x: x.strip())
df.company_hash
# Out:
# 0                    czniswwz sucsk
# 1         oznskulz subilihh nshswzc
# 2                     faulwklwsl ks
# 3                         wirijzcsk
# 4                        osbw toidj
#                     ...
# 205838                    kjjnz sul
# 205839                    djtokclih
# 205840                     kllinswz
# 205841               uiw kjjnslkgnz
# 205842               hiotku fwkunza
# Name: company_hash, Length: 188247, dtype: object

# %%
df['company_hash'].value_counts().sort_index()
# Out:
#                                     85
# a h hiwiof jvw nwc                   1
# a h n                                2
# a hzcsk nkgf                        29
# a kysf findwsiuf josvkwz nshswzc     2
#                                     ..
# zzhjekfaf nwc                        1
# zzhzqz fibw wzle                     1
# zzm wzleuinitszf                     3
# zzqansbz sul                         1
# zzqaukdrkos                          1
# Name: company_hash, Length: 37208, dtype: int64

# %%
print(df.shape)
print(df.drop_duplicates().shape)
df.drop_duplicates(inplace=True)
# Out:
# (188247, 5)
# (188246, 5)

# %%
#removing rows where company or job_position is not available
df=df[ ~((df['company_hash']=='') | (df['job_position']==''))]

# %%
df.shape
# Out:
# (188153, 5)

# %% [markdown]
# ### Filling Null values using Mean Target Inputation for Orgyear

# %%
df['orgyear'].isnull().sum()
# Out:
# 86

# %%
company_median_org_year=df.groupby('company_hash')['orgyear'].median()

# %%
company_median_org_year
# Out:
# company_hash
# a h hiwiof jvw nwc                  2006.0
# a h n                               2016.0
# a hzcsk nkgf                        2014.0
# a kysf findwsiuf josvkwz nshswzc    2013.0
# adadfwd suwodhzuwf                  2012.0
#                                      ...
# zzhjekfaf nwc                       2012.0
# zzhzqz fibw wzle                    2011.0
# zzm wzleuinitszf                    2016.0
# zzqansbz sul                        2017.0
# zzqaukdrkos                         2013.0
# Name: orgyear, Length: 37205, dtype: float64

# %%
#Code to impute
#-----------------------------------------------------------------------
import numpy as np
def null_imputation(table_from_which_we_need_to_fill, main_col, null_col):
    if np.isnan(null_col):
        return table_from_which_we_need_to_fill[main_col]
    else:
        return null_col
#-----------------------------------------------------------------------


df['orgyear']=df.apply(lambda x: null_imputation(company_median_org_year,x['company_hash'],x['orgyear'] ), axis=1)
# Out:
# /var/folders/qc/486wrwtd4mj2pdzxt66k36c00000gn/T/ipykernel_8139/3886512092.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['orgyear']=df.apply(lambda x: null_imputation(company_median_org_year,x['company_hash'],x['orgyear'] ), axis=1)

# %%
#you can try the null value imputation using kNN imputation as well

# %%
#if we still have null values, we'll drop it
len(df[df['orgyear'].isnull()])
# Out:
# 26

# %%
#dropping remaining null values
df=df[~df['orgyear'].isnull()]

# %% [markdown]
# ### Checking for outliers in orgyear

# %%
#simple understanding
df.orgyear.value_counts().sort_values(ascending=True)
# Out:
# 200.0          1
# 208.0          1
# 38.0           1
# 2204.0         1
# 1900.0         1
# 201.0          1
# 2011.5         1
# 83.0           1
# 4.0            1
# 1977.0         1
# 1979.0         1
# 209.0          1
# 1971.0         1
# 2101.0         1
# 1972.0         1
# 2107.0         1
# 206.0          1
# 2106.0         1
# 1973.0         1
# 1981.0         1
# 2027.0         1
# 1976.0         1
# 20165.0        2
# 1970.0         2
# 5.0            2
# 1.0            2
# 2014.5         2
# 6.0            2
# 91.0           3
# 1984.0         3
# 2.0            3
# 1982.0         4
# 2028.0         4
# 2029.0         5
# 2031.0         5
# 1985.0         5
# 3.0            6
# 1987.0         6
# 1986.0         8
# 2026.0         9
# 1988.0        10
# 2025.0        12
# 0.0           17
# 1989.0        22
# 1990.0        38
# 2024.0        43
# 1992.0        47
# 1994.0        65
# 1993.0        72
# 1991.0        79
# 1995.0        94
# 1996.0       134
# 1997.0       234
# 2023.0       245
# 1998.0       279
# 1999.0       338
# 2000.0       491
# 2002.0       683
# 2001.0       708
# 2022.0       836
# 2003.0      1010
# 2004.0      1448
# 2005.0      1859
# 2006.0      2066
# 2007.0      2230
# 2008.0      2688
# 2021.0      3143
# 2009.0      3738
# 2010.0      5646
# 2011.0      7802
# 2012.0     10257
# 2020.0     10434
# 2013.0     12054
# 2014.0     16092
# 2019.0     18551
# 2015.0     19613
# 2017.0     21320
# 2016.0     21477
# 2018.0     22157
# Name: orgyear, dtype: int64

# %%
#removing outliers from orgyear using IQR

q1=df.orgyear.quantile(0.25)
q3=df.orgyear.quantile(0.75)
iqr=q3-q1

df=df.loc[(df.orgyear>=q1-1.5*iqr) & (df.orgyear<=q3+1.5*iqr)]


#removing outliers from ctc using IQR

q1=df.ctc.quantile(0.25)
q3=df.ctc.quantile(0.75)
iqr=q3-q1

df=df.loc[(df.ctc>=q1-1.5*iqr) & (df.ctc<=q3+1.5*iqr)]

# %%
df.orgyear.value_counts().sort_index(ascending=True)
# Out:
# 2006.0     1635
# 2007.0     1821
# 2008.0     2279
# 2009.0     3215
# 2010.0     5004
# 2011.0     7023
# 2011.5        1
# 2012.0     9366
# 2013.0    11134
# 2014.0    15090
# 2014.5        2
# 2015.0    18535
# 2016.0    20394
# 2017.0    20421
# 2018.0    21335
# 2019.0    17910
# 2020.0     9940
# 2021.0     2900
# 2022.0      739
# 2023.0      200
# 2024.0       32
# 2025.0       11
# Name: orgyear, dtype: int64

# %%
print(df.shape)
print(df.drop_duplicates().shape)
df.drop_duplicates(inplace=True)
# Out:
# (168987, 5)
# (168986, 5)

# %%
df
# Out:
#                      company_hash  orgyear      ctc        job_position  \
# 0                  czniswwz sucsk   2016.0  1100000               other
# 1       oznskulz subilihh nshswzc   2018.0   449999  fullstack engineer
# 2                   faulwklwsl ks   2015.0  2000000    backend engineer
# 3                       wirijzcsk   2017.0   700000    backend engineer
# 4                      osbw toidj   2017.0  1400000  fullstack engineer
# ...                           ...      ...      ...                 ...
# 205836                   gkolnkaf   2011.0  2250000                 nan
# 205838                  kjjnz sul   2008.0   220000                 nan
# 205839                  djtokclih   2017.0   500000                 nan
# 205840                   kllinswz   2021.0   700000                 nan
# 205842             hiotku fwkunza   2014.0  1240000                 nan
#
#         ctc_updated_year
# 0                 2020.0
# 1                 2019.0
# 2                 2020.0
# 3                 2019.0
# 4                 2019.0
# ...                  ...
# 205836            2019.0
# 205838            2019.0
# 205839            2020.0
# 205840            2021.0
# 205842            2016.0
#
# [168986 rows x 5 columns]

# %%
#We see some 'nan's in job_position
df.loc[df['job_position']=='nan','job_position']=np.nan

# %% [markdown]
# ## Masking companies by renaming it to "Others" having count less than 5

# %%
#making the code
df.company_hash.value_counts()
# Out:
# wkwk liufdnwkula fzovslzf    4111
# subifaf                      2910
# khkqiu                       2226
# litusqkuw                    2115
# kllzuwdoz                    1998
#                              ...
# gkol sucsk                      1
# liuwido                         1
# joihklw subiwzle jvw nwc        1
# hkvzoslrf mzg fzovslzf          1
# lekowzo lihhduslkwsiuf          1
# Name: company_hash, Length: 34008, dtype: int64

# %%
df[df.company_hash.map(df.company_hash.value_counts())<=5]
# Out:
#                   company_hash  orgyear      ctc            job_position  \
# 2                faulwklwsl ks   2015.0  2000000        backend engineer
# 9                        snhdy   2019.0   360000                     NaN
# 11                  wiyfn wzle   2016.0   600000            ios engineer
# 16           rwl sucsk jvw nwc   2013.0   800000                   other
# 21                 csiu tnigkn   2006.0  1550000  engineering leadership
# ...                        ...      ...      ...                     ...
# 205811      gndz fwkwz cstswkn   2013.0    85000                     NaN
# 205815    hkrzhawosj zy khkqiu   2015.0  2400000                     NaN
# 205816      licz bnim wzle nnj   2019.0  2200000                     NaN
# 205817            lsfli fawzhf   2011.0  3327000                     NaN
# 205834  lekowzo lihhduslkwsiuf   2020.0   100000                     NaN
#
#         ctc_updated_year
# 2                 2020.0
# 9                 2019.0
# 11                2021.0
# 16                2020.0
# 21                2019.0
# ...                  ...
# 205811            2016.0
# 205815            2019.0
# 205816            2020.0
# 205817            2019.0
# 205834            2019.0
#
# [46749 rows x 5 columns]

# %%
df['new']=df.company_hash.mask(df.company_hash.map(df.company_hash.value_counts())<=5,'Others')

# %%
df
# Out:
#                      company_hash  orgyear      ctc        job_position  \
# 0                  czniswwz sucsk   2016.0  1100000               other
# 1       oznskulz subilihh nshswzc   2018.0   449999  fullstack engineer
# 2                   faulwklwsl ks   2015.0  2000000    backend engineer
# 3                       wirijzcsk   2017.0   700000    backend engineer
# 4                      osbw toidj   2017.0  1400000  fullstack engineer
# ...                           ...      ...      ...                 ...
# 205836                   gkolnkaf   2011.0  2250000                 NaN
# 205838                  kjjnz sul   2008.0   220000                 NaN
# 205839                  djtokclih   2017.0   500000                 NaN
# 205840                   kllinswz   2021.0   700000                 NaN
# 205842             hiotku fwkunza   2014.0  1240000                 NaN
#
#         ctc_updated_year                        new
# 0                 2020.0             czniswwz sucsk
# 1                 2019.0  oznskulz subilihh nshswzc
# 2                 2020.0                     Others
# 3                 2019.0                  wirijzcsk
# 4                 2019.0                 osbw toidj
# ...                  ...                        ...
# 205836            2019.0                   gkolnkaf
# 205838            2019.0                  kjjnz sul
# 205839            2020.0                  djtokclih
# 205840            2021.0                   kllinswz
# 205842            2016.0             hiotku fwkunza
#
# [168986 rows x 6 columns]

# %%
df[df['new']=='Others'].company_hash.value_counts()
# Out:
# sufeiowf                   5
# hafleiinjktz               5
# hahiuzarkohk               5
# liuwsuzuwkn kt             5
# nzwf wokufjiow             5
#                           ..
# dgzowkn                    1
# joihkw                     1
# pr wzleuifibw nwc uisck    1
# tiintz                     1
# lekowzo lihhduslkwsiuf     1
# Name: company_hash, Length: 31066, dtype: int64

# %%
#now connecting the dots

# %%
df=df.apply(lambda x: x.mask(x.map(x.value_counts())<=5,'Others') if x.name=='company_hash' else x)

# %%
df.company_hash.value_counts()
# Out:
# Others                        46749
# wkwk liufdnwkula fzovslzf      4111
# subifaf                        2910
# khkqiu                         2226
# litusqkuw                      2115
#                               ...
# ckflzx                            6
# fkccnz jisuw wzleuinitszf         6
# sufwkuw fafwzhf sul               6
# kntiflknz wzleuinitszf sul        6
# fdhwiwkn fafwzhf                  6
# Name: company_hash, Length: 2943, dtype: int64

# %%
df.drop(columns='new',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/qc/486wrwtd4mj2pdzxt66k36c00000gn/T/ipykernel_8139/651640861.py in <module>
# ----> 1 df.drop(columns='new',inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['new'] not found in axis"

# %% [markdown]
# #### Creating Years of Experience Columns

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (147140, 5)

# %%
#orgyear check
df['orgyear'] = df.apply(lambda x: x['orgyear'] if x['orgyear'] <=
                     2022 else 2022, axis=1)

# %%
df['years_of_experience']=2022-df['orgyear']

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (147101, 6)

# %%
df=df[~df['years_of_experience'].isnull()]

# %%
#ctc_updated_year_check
df['ctc_updated_year'] = df.apply(lambda x: x['orgyear'] if x['ctc_updated_year'] <
                     x['orgyear'] else x['ctc_updated_year'], axis=1)

# %%
#Filling null values with others  -- if not done before
df['job_position'] = df['job_position'].fillna('Others')
df['company_hash'] = df['company_hash'].fillna('Others')

# %%
df.isnull().sum()
#All good now
# Out:
# company_hash           0
# orgyear                0
# ctc                    0
# job_position           0
# ctc_updated_year       0
# years_of_experience    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (146053, 6)

# %%
df.describe()
# Out:
#              orgyear           ctc  ctc_updated_year  years_of_experience
# count  146053.000000  1.460530e+05     146053.000000        146053.000000
# mean     2015.449409  1.129327e+06       2019.598454             6.550591
# std         3.300264  7.439632e+05          1.339107             3.300264
# min      2006.000000  2.000000e+00       2015.000000             0.000000
# 25%      2013.000000  5.700000e+05       2019.000000             4.000000
# 50%      2016.000000  9.600000e+05       2020.000000             6.000000
# 75%      2018.000000  1.560000e+06       2021.000000             9.000000
# max      2022.000000  3.330000e+06       2022.000000            16.000000

# %%
#pd.DataFrame(df['job_position'].value_counts()).to_csv('scaler_job_positions.csv')

# %% [markdown]
# # Spell Check or Manual mapping to fix the errors in Job Titles

# %%
# find those words that may be misspelled
#from spellchecker import SpellChecker

#spell = SpellChecker()

#misspelled = spell.unknown(list(df['company'].values)[:10])
#dicter={}
#for word in misspelled:
    # Get the one `most likely` answer
#    dicter[word]=spell.correction(word)

#print(dicter)

# %%
#merge the mapping with the original one
job_map=pd.read_csv('scaler_job_positions_mapping VX.csv')

# %%
job_map[:100]
# Out:
#                                   Original  \
# 0                                        7
# 1                                       91
# 2                                      737
# 3                                   857628
# 4                                   896651
# 5                 a group chat application
# 6                           abap developer
# 7                                  account
# 8                     administrative clerk
# 9                            administrator
# 10                                 advisor
# 11              advisory software engineer
# 12                 advisory system analyat
# 13               agency collection manager
# 14                             ai engineer
# 15                               air force
# 16              analyst  software engineer
# 17                      analyst consultant
# 18                      analyst programmer
# 19           analytics and insite devloper
# 20           android application developer
# 21          android developer sr executive
# 22                        android engineer
# 23                     android facilitator
# 24                            android lead
# 25                           any technical
# 26                           app developer
# 27                 application developer 1
# 28                 application developer 2
# 29           application developer analyst
# 30          application developer frontend
# 31                 application development
# 32         application development analyst
# 33       application development associate
# 34  application development senior analyst
# 35       application development team lead
# 36       application developmentaassociate
# 37                    application engineer
# 38                 application engineer ii
# 39                   applications engineer
# 40                    applied scientist ii
# 41                     architect team lead
# 42                   area business manager
# 43                 area operations manager
# 44                                     ase
# 45                        aspnet developer
# 46            asset management coordinator
# 47               assisatnt system engineer
# 48                               assistant
# 49                      assistant engineer
# 50              assistant engineer trainee
# 51                       assistant manager
# 52                     assistant professor
# 53        assistant regional sales manager
# 54             assistant software engineer
# 55               assistant system engineer
# 56      assistant system engineer  trainee
# 57       assistant system engineer trainee
# 58               assistant system enginner
# 59                               associate
# 60           associate  software  engineer
# 61                       associate analyst
# 62         associate application developer
# 63          associate application engineer
# 64        associate applications developer
# 65                         associate coder
# 66                    associate consultant
# 67         associate consultant  developer
# 68                 associate data engineer
# 69                associate data scientist
# 70                     associate developer
# 71                      associate engineer
# 72      associate futures engineering team
# 73      associate interactive developer l2
# 74                   associate it engineer
# 75                            associate l1
# 76                       associate manager
# 77                     associate processor
# 78                  associate product lead
# 79               associate product manager
# 80                  associate professional
# 81        associate professional developer
# 82            associate software developer
# 83             associate software engineer
# 84               associate system engineer
# 85      associate system engineer  trainee
# 86        associate system engineertrainee
# 87                     associate tech lead
# 88            associate technical engineer
# 89                associate technical lead
# 90             associate technical support
# 91                    associate technology
# 92               assosiate product manager
# 93             assosiate software engineer
# 94                            asst manager
# 95                    atm interface system
# 96                           audit manager
# 97                                auditing
# 98                                 auditor
# 99                    automation architect
#
#                                        New
# 0                                   others
# 1                                   others
# 2                                   others
# 3                                   others
# 4                                   others
# 5                                   others
# 6                           abap developer
# 7                                  account
# 8                     administrative clerk
# 9                            administrator
# 10                                 advisor
# 11              advisory software engineer
# 12                 advisory system analyst
# 13               agency collection manager
# 14                             ai engineer
# 15                               air force
# 16               analyst software engineer
# 17                      analyst consultant
# 18                      analyst programmer
# 19           analytics and insite devloper
# 20           android application developer
# 21          android developer sr executive
# 22                        android engineer
# 23                     android facilitator
# 24                            android lead
# 25                           any technical
# 26                           app developer
# 27                 application developer 1
# 28                 application developer 2
# 29           application developer analyst
# 30          application developer frontend
# 31                 application development
# 32         application development analyst
# 33       application development associate
# 34  application development senior analyst
# 35       application development team lead
# 36      application development aassociate
# 37                 application developer 1
# 38                 application developer 2
# 39                 application developer 1
# 40                     applied scientist 2
# 41                     architect team lead
# 42                   area business manager
# 43                 area operations manager
# 44         application development analyst
# 45                        aspnet developer
# 46            asset management coordinator
# 47               assisatnt system engineer
# 48                               assistant
# 49                      assistant engineer
# 50              assistant engineer trainee
# 51                       assistant manager
# 52                     assistant professor
# 53        assistant regional sales manager
# 54             assistant software engineer
# 55               assistant system engineer
# 56       assistant system engineer trainee
# 57       assistant system engineer trainee
# 58               assistant system engineer
# 59                               associate
# 60             associate software engineer
# 61                       associate analyst
# 62         associate application developer
# 63         associate application developer
# 64         associate application developer
# 65                         associate coder
# 66                    associate consultant
# 67          associate consultant developer
# 68                 associate data engineer
# 69                associate data scientist
# 70                     associate developer
# 71                     associate developer
# 72      associate futures engineering team
# 73      associate interactive developer l2
# 74                   associate it engineer
# 75                            associate l1
# 76                       associate manager
# 77                     associate processor
# 78                  associate product lead
# 79               associate product manager
# 80        associate professional developer
# 81        associate professional developer
# 82            associate software developer
# 83            associate software developer
# 84               associate system engineer
# 85       associate system engineer trainee
# 86       associate system engineer trainee
# 87                     associate tech lead
# 88            associate technical engineer
# 89                associate technical lead
# 90             associate technical support
# 91                    associate technology
# 92               assosiate product manager
# 93             assosiate software engineer
# 94                            asst manager
# 95                    atm interface system
# 96                           audit manager
# 97                                 auditor
# 98                                 auditor
# 99                    automation architect

# %%
job_map.shape
# Out:
# (801, 2)

# %%
job_map.drop_duplicates(inplace=True)

# %%
df=df.merge(job_map, left_on='job_position', right_on='Original', how='left')

# %%
df.shape
# Out:
# (146053, 8)

# %%
df.isnull().sum()
# Out:
# company_hash               0
# orgyear                    0
# ctc                        0
# job_position               0
# ctc_updated_year           0
# years_of_experience        0
# Original               32974
# New                    32974
# dtype: int64

# %%
df.drop(columns=['job_position','Original'],inplace=True)
df['job_position']=df['New']
df.drop(columns=['New'],inplace=True)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (145726, 6)

# %%
df=df[~(df['job_position'].isnull())]

# %%
df.shape
# Out:
# (112824, 6)

# %% [markdown]
# ## Manual Clustering based on company, job position and years of experience

# %%
grouped_c_j_y=df.groupby(['years_of_experience','job_position','company_hash'])['ctc'].describe()

# %%
grouped_c_j_y
# Out:
#                                                                   count  \
# years_of_experience job_position       company_hash
# 0.0                 analyst programmer Others                       1.0
#                     android engineer   Others                       5.0
#                                        esrz hzffzutzo               1.0
#                                        kllzuwdoz                    1.0
#                                        sh  k fwdczuw                2.0
# ...                                                                 ...
# 16.0                support engineer   subio                        1.0
#                                        tf nkg                       1.0
#                                        uku                          1.0
#                                        wkwk liufdnwkula fzovslzf    1.0
#                     team lead          jzofsfwzuw fafwzhf           1.0
#
#                                                                        mean  \
# years_of_experience job_position       company_hash
# 0.0                 analyst programmer Others                      360000.0
#                     android engineer   Others                      706000.0
#                                        esrz hzffzutzo              300000.0
#                                        kllzuwdoz                   450000.0
#                                        sh  k fwdczuw              1350000.0
# ...                                                                     ...
# 16.0                support engineer   subio                       900000.0
#                                        tf nkg                     1350000.0
#                                        uku                         400000.0
#                                        wkwk liufdnwkula fzovslzf  1500000.0
#                     team lead          jzofsfwzuw fafwzhf         1600000.0
#
#                                                                            std  \
# years_of_experience job_position       company_hash
# 0.0                 analyst programmer Others                              NaN
#                     android engineer   Others                     4.417918e+05
#                                        esrz hzffzutzo                      NaN
#                                        kllzuwdoz                           NaN
#                                        sh  k fwdczuw              1.626346e+06
# ...                                                                        ...
# 16.0                support engineer   subio                               NaN
#                                        tf nkg                              NaN
#                                        uku                                 NaN
#                                        wkwk liufdnwkula fzovslzf           NaN
#                     team lead          jzofsfwzuw fafwzhf                  NaN
#
#                                                                         min  \
# years_of_experience job_position       company_hash
# 0.0                 analyst programmer Others                      360000.0
#                     android engineer   Others                      100000.0
#                                        esrz hzffzutzo              300000.0
#                                        kllzuwdoz                   450000.0
#                                        sh  k fwdczuw               200000.0
# ...                                                                     ...
# 16.0                support engineer   subio                       900000.0
#                                        tf nkg                     1350000.0
#                                        uku                         400000.0
#                                        wkwk liufdnwkula fzovslzf  1500000.0
#                     team lead          jzofsfwzuw fafwzhf         1600000.0
#
#                                                                         25%  \
# years_of_experience job_position       company_hash
# 0.0                 analyst programmer Others                      360000.0
#                     android engineer   Others                      480000.0
#                                        esrz hzffzutzo              300000.0
#                                        kllzuwdoz                   450000.0
#                                        sh  k fwdczuw               775000.0
# ...                                                                     ...
# 16.0                support engineer   subio                       900000.0
#                                        tf nkg                     1350000.0
#                                        uku                         400000.0
#                                        wkwk liufdnwkula fzovslzf  1500000.0
#                     team lead          jzofsfwzuw fafwzhf         1600000.0
#
#                                                                         50%  \
# years_of_experience job_position       company_hash
# 0.0                 analyst programmer Others                      360000.0
#                     android engineer   Others                      700000.0
#                                        esrz hzffzutzo              300000.0
#                                        kllzuwdoz                   450000.0
#                                        sh  k fwdczuw              1350000.0
# ...                                                                     ...
# 16.0                support engineer   subio                       900000.0
#                                        tf nkg                     1350000.0
#                                        uku                         400000.0
#                                        wkwk liufdnwkula fzovslzf  1500000.0
#                     team lead          jzofsfwzuw fafwzhf         1600000.0
#
#                                                                         75%  \
# years_of_experience job_position       company_hash
# 0.0                 analyst programmer Others                      360000.0
#                     android engineer   Others                     1050000.0
#                                        esrz hzffzutzo              300000.0
#                                        kllzuwdoz                   450000.0
#                                        sh  k fwdczuw              1925000.0
# ...                                                                     ...
# 16.0                support engineer   subio                       900000.0
#                                        tf nkg                     1350000.0
#                                        uku                         400000.0
#                                        wkwk liufdnwkula fzovslzf  1500000.0
#                     team lead          jzofsfwzuw fafwzhf         1600000.0
#
#                                                                         max
# years_of_experience job_position       company_hash
# 0.0                 analyst programmer Others                      360000.0
#                     android engineer   Others                     1200000.0
#                                        esrz hzffzutzo              300000.0
#                                        kllzuwdoz                   450000.0
#                                        sh  k fwdczuw              2500000.0
# ...                                                                     ...
# 16.0                support engineer   subio                       900000.0
#                                        tf nkg                     1350000.0
#                                        uku                         400000.0
#                                        wkwk liufdnwkula fzovslzf  1500000.0
#                     team lead          jzofsfwzuw fafwzhf         1600000.0
#
# [45407 rows x 8 columns]

# %%
df_cjy=df.merge(grouped_c_j_y, on=['years_of_experience','job_position','company_hash'], how='left')

# %%
df_cjy.sort_values(['years_of_experience','job_position','company_hash'])
# Out:
#                     company_hash  orgyear      ctc  ctc_updated_year  \
# 19778                     Others   2022.0   360000            2022.0
# 3354                      Others   2022.0   480000            2022.0
# 13161                     Others   2022.0  1200000            2022.0
# 23736                     Others   2022.0   100000            2022.0
# 82918                     Others   2022.0  1050000            2022.0
# ...                          ...      ...      ...               ...
# 56015                      subio   2006.0   900000            2021.0
# 75812                     tf nkg   2006.0  1350000            2019.0
# 10672                        uku   2006.0   400000            2021.0
# 27315  wkwk liufdnwkula fzovslzf   2006.0  1500000            2021.0
# 44348         jzofsfwzuw fafwzhf   2006.0  1600000            2021.0
#
#        years_of_experience        job_position  count       mean  \
# 19778                  0.0  analyst programmer    1.0   360000.0
# 3354                   0.0    android engineer    5.0   706000.0
# 13161                  0.0    android engineer    5.0   706000.0
# 23736                  0.0    android engineer    5.0   706000.0
# 82918                  0.0    android engineer    5.0   706000.0
# ...                    ...                 ...    ...        ...
# 56015                 16.0    support engineer    1.0   900000.0
# 75812                 16.0    support engineer    1.0  1350000.0
# 10672                 16.0    support engineer    1.0   400000.0
# 27315                 16.0    support engineer    1.0  1500000.0
# 44348                 16.0           team lead    1.0  1600000.0
#
#                  std        min        25%        50%        75%        max
# 19778            NaN   360000.0   360000.0   360000.0   360000.0   360000.0
# 3354   441791.806171   100000.0   480000.0   700000.0  1050000.0  1200000.0
# 13161  441791.806171   100000.0   480000.0   700000.0  1050000.0  1200000.0
# 23736  441791.806171   100000.0   480000.0   700000.0  1050000.0  1200000.0
# 82918  441791.806171   100000.0   480000.0   700000.0  1050000.0  1200000.0
# ...              ...        ...        ...        ...        ...        ...
# 56015            NaN   900000.0   900000.0   900000.0   900000.0   900000.0
# 75812            NaN  1350000.0  1350000.0  1350000.0  1350000.0  1350000.0
# 10672            NaN   400000.0   400000.0   400000.0   400000.0   400000.0
# 27315            NaN  1500000.0  1500000.0  1500000.0  1500000.0  1500000.0
# 44348            NaN  1600000.0  1600000.0  1600000.0  1600000.0  1600000.0
#
# [112824 rows x 14 columns]

# %%
df_cjy.drop_duplicates(inplace=True)
df_cjy.shape
#no change till now
# Out:
# (112824, 14)

# %% [markdown]
# ### Creating Designation basis on the salary they are getting in their respective company

# %%
def condition_designation(a,b_50,b_75):
    if a<b_50:
        return 3
    elif a>=b_50 and a<=b_75:
        return 2

    elif a>=b_75:
        return 1

# %%
df.head()
# Out:
#                 company_hash  orgyear      ctc  ctc_updated_year  \
# 0             czniswwz sucsk   2016.0  1100000            2020.0
# 1  oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                     Others   2015.0  2000000            2020.0
# 3                  wirijzcsk   2017.0   700000            2019.0
# 4                 osbw toidj   2017.0  1400000            2019.0
#
#    years_of_experience        job_position
# 0                  6.0              others
# 1                  4.0  fullstack devloper
# 2                  7.0    backend engineer
# 3                  5.0    backend engineer
# 4                  5.0  fullstack devloper

# %%
df_cjy['designation'] =df_cjy.apply(lambda x: condition_designation(x['ctc'],x['50%'],x['75%']),axis=1)

# %%
df_cjy.head()
# Out:
#                 company_hash  orgyear      ctc  ctc_updated_year  \
# 0             czniswwz sucsk   2016.0  1100000            2020.0
# 1  oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                     Others   2015.0  2000000            2020.0
# 3                  wirijzcsk   2017.0   700000            2019.0
# 4                 osbw toidj   2017.0  1400000            2019.0
#
#    years_of_experience        job_position  count          mean  \
# 0                  6.0              others    1.0  1.100000e+06
# 1                  4.0  fullstack devloper    7.0  7.742856e+05
# 2                  7.0    backend engineer  456.0  9.609559e+05
# 3                  5.0    backend engineer    7.0  1.158571e+06
# 4                  5.0  fullstack devloper    1.0  1.400000e+06
#
#              std        min        25%        50%        75%        max  \
# 0            NaN  1100000.0  1100000.0  1100000.0  1100000.0  1100000.0
# 1  250922.324350   449999.0   610000.0   750000.0   900000.0  1200000.0
# 2  776546.830662     1000.0   307500.0   800000.0  1435000.0  3200000.0
# 3  404780.951933   700000.0   825000.0  1200000.0  1405000.0  1750000.0
# 4            NaN  1400000.0  1400000.0  1400000.0  1400000.0  1400000.0
#
#    designation
# 0            2
# 1            3
# 2            1
# 3            3
# 4            2

# %%
df_cjy.designation.value_counts(normalize=True)*100
# Out:
# 2    45.435368
# 3    33.298766
# 1    21.265865
# Name: designation, dtype: float64

# %% [markdown]
# ## Manual Clustering based on company and job position

# %%
grouped_c_j=df.groupby(['job_position','company_hash'])['ctc'].describe()

# %%
grouped_c_j
# Out:
#                                                       count       mean  std  \
# job_position             company_hash
# abap developer           Others                         1.0   500000.0  NaN
# account                  uiw kjjnslkgnz klliduw         1.0  2000000.0  NaN
# administrative clerk     Others                         1.0   500000.0  NaN
# administrator            Others                         1.0   380000.0  NaN
# advisor                  bsf                            1.0   360000.0  NaN
# ...                                                     ...        ...  ...
# web designer intern      wez fjkorf biduckwsiu          1.0   420000.0  NaN
# web developer full stack kuiwezo lihjkua                1.0   300000.0  NaN
# webcenter consultant     nkofzu  widgoi subiwzle nwc    1.0   300000.0  NaN
# wordpress developer      Others                         1.0   600000.0  NaN
# young professional 2     tivzouhzuw ib sucsk            1.0   500000.0  NaN
#
#                                                             min        25%  \
# job_position             company_hash
# abap developer           Others                        500000.0   500000.0
# account                  uiw kjjnslkgnz klliduw       2000000.0  2000000.0
# administrative clerk     Others                        500000.0   500000.0
# administrator            Others                        380000.0   380000.0
# advisor                  bsf                           360000.0   360000.0
# ...                                                         ...        ...
# web designer intern      wez fjkorf biduckwsiu         420000.0   420000.0
# web developer full stack kuiwezo lihjkua               300000.0   300000.0
# webcenter consultant     nkofzu  widgoi subiwzle nwc   300000.0   300000.0
# wordpress developer      Others                        600000.0   600000.0
# young professional 2     tivzouhzuw ib sucsk           500000.0   500000.0
#
#                                                             50%        75%  \
# job_position             company_hash
# abap developer           Others                        500000.0   500000.0
# account                  uiw kjjnslkgnz klliduw       2000000.0  2000000.0
# administrative clerk     Others                        500000.0   500000.0
# administrator            Others                        380000.0   380000.0
# advisor                  bsf                           360000.0   360000.0
# ...                                                         ...        ...
# web designer intern      wez fjkorf biduckwsiu         420000.0   420000.0
# web developer full stack kuiwezo lihjkua               300000.0   300000.0
# webcenter consultant     nkofzu  widgoi subiwzle nwc   300000.0   300000.0
# wordpress developer      Others                        600000.0   600000.0
# young professional 2     tivzouhzuw ib sucsk           500000.0   500000.0
#
#                                                             max
# job_position             company_hash
# abap developer           Others                        500000.0
# account                  uiw kjjnslkgnz klliduw       2000000.0
# administrative clerk     Others                        500000.0
# administrator            Others                        380000.0
# advisor                  bsf                           360000.0
# ...                                                         ...
# web designer intern      wez fjkorf biduckwsiu         420000.0
# web developer full stack kuiwezo lihjkua               300000.0
# webcenter consultant     nkofzu  widgoi subiwzle nwc   300000.0
# wordpress developer      Others                        600000.0
# young professional 2     tivzouhzuw ib sucsk           500000.0
#
# [18533 rows x 8 columns]

# %%
df
# Out:
#                      company_hash  orgyear      ctc  ctc_updated_year  \
# 0                  czniswwz sucsk   2016.0  1100000            2020.0
# 1       oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                          Others   2015.0  2000000            2020.0
# 3                       wirijzcsk   2017.0   700000            2019.0
# 4                      osbw toidj   2017.0  1400000            2019.0
# ...                           ...      ...      ...               ...
# 145701                     ioklnz   2019.0   950000            2021.0
# 145702            jinslagkqkkolih   2021.0  1000000            2021.0
# 145704          lft suwzoukwsiukn   2016.0  1500000            2021.0
# 145705                  cduuedhga   2019.0  1100000            2021.0
# 145706                     Others   2017.0  1100000            2021.0
#
#         years_of_experience        job_position
# 0                       6.0              others
# 1                       4.0  fullstack devloper
# 2                       7.0    backend engineer
# 3                       5.0    backend engineer
# 4                       5.0  fullstack devloper
# ...                     ...                 ...
# 145701                  3.0    backend engineer
# 145702                  1.0    backend engineer
# 145704                  6.0  fullstack devloper
# 145705                  3.0      data scientist
# 145706                  5.0  frontend developer
#
# [112824 rows x 6 columns]

# %%
df.drop_duplicates().shape
# Out:
# (112824, 6)

# %%
df_cj=df.merge(grouped_c_j, on=['job_position','company_hash'], how='left')

# %%
df_cj
# Out:
#                      company_hash  orgyear      ctc  ctc_updated_year  \
# 0                  czniswwz sucsk   2016.0  1100000            2020.0
# 1       oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                          Others   2015.0  2000000            2020.0
# 3                       wirijzcsk   2017.0   700000            2019.0
# 4                      osbw toidj   2017.0  1400000            2019.0
# ...                           ...      ...      ...               ...
# 112819                     ioklnz   2019.0   950000            2021.0
# 112820            jinslagkqkkolih   2021.0  1000000            2021.0
# 112821          lft suwzoukwsiukn   2016.0  1500000            2021.0
# 112822                  cduuedhga   2019.0  1100000            2021.0
# 112823                     Others   2017.0  1100000            2021.0
#
#         years_of_experience        job_position   count          mean  \
# 0                       6.0              others     2.0  1.085000e+06
# 1                       4.0  fullstack devloper    25.0  9.882000e+05
# 2                       7.0    backend engineer  3871.0  1.001007e+06
# 3                       5.0    backend engineer    24.0  1.416667e+06
# 4                       5.0  fullstack devloper     3.0  8.466667e+05
# ...                     ...                 ...     ...           ...
# 112819                  3.0    backend engineer   633.0  1.447947e+06
# 112820                  1.0    backend engineer    16.0  1.089375e+06
# 112821                  6.0  fullstack devloper     7.0  1.481429e+06
# 112822                  3.0      data scientist    26.0  1.214154e+06
# 112823                  5.0  frontend developer  1809.0  8.950238e+05
#
#                   std        min         25%        50%        75%        max
# 0        21213.203436  1070000.0  1077500.00  1085000.0  1092500.0  1100000.0
# 1       487499.789590   300000.0   600000.00   850000.0  1380000.0  2000000.0
# 2       812465.827695     1000.0   300000.00   830000.0  1530000.0  3300000.0
# 3       545341.270627   520000.0  1047500.00  1375000.0  1792500.0  2600000.0
# 4       480138.868801   540000.0   570000.00   600000.0  1000000.0  1400000.0
# ...               ...        ...         ...        ...        ...        ...
# 112819  702632.095190     7500.0   950000.00  1300000.0  1900000.0  3300000.0
# 112820  519249.085299   330000.0   819999.25   965000.0  1325000.0  2500000.0
# 112821  659353.940648   550000.0  1050000.00  1500000.0  1860000.0  2500000.0
# 112822  448166.994975    31000.0  1025000.00  1195000.0  1400000.0  2000000.0
# 112823  649888.886024     1000.0   400000.00   810000.0  1240000.0  3300000.0
#
# [112824 rows x 14 columns]

# %%
df_cj.sort_values(['company_hash','job_position','years_of_experience'])
# [df_cj.sort_values(['company','job_position','years_of_experience'])['company']=='Amazon'][:2]
# df_cj.sort_values(['company','job_position','years_of_experience'])[df_cj.sort_values(['company','job_position','years_of_experience'])['company']=='Amazon'][:2]
# Out:
#        company_hash  orgyear      ctc  ctc_updated_year  years_of_experience  \
# 46958        Others   2018.0   500000            2021.0                  4.0
# 20396        Others   2015.0   500000            2021.0                  7.0
# 2800         Others   2020.0   380000            2020.0                  2.0
# 39108        Others   2016.0  1290000            2019.0                  6.0
# 24075        Others   2010.0   360000            2021.0                 12.0
# ...             ...      ...      ...               ...                  ...
# 82661    zyyiuhigsn   2012.0  1800000            2019.0                 10.0
# 100656   zyyiuhigsn   2010.0  2500000            2019.0                 12.0
# 50156    zyyiuhigsn   2011.0  2400000            2019.0                 11.0
# 2791     zyyiuhigsn   2018.0  1900000            2021.0                  4.0
# 94157    zyyiuhigsn   2018.0  1150000            2019.0                  4.0
#
#                       job_position  count       mean           std        min  \
# 46958               abap developer    1.0   500000.0           NaN   500000.0
# 20396         administrative clerk    1.0   500000.0           NaN   500000.0
# 2800                 administrator    1.0   380000.0           NaN   380000.0
# 39108   advisory software engineer    1.0  1290000.0           NaN  1290000.0
# 24075    agency collection manager    1.0   360000.0           NaN   360000.0
# ...                            ...    ...        ...           ...        ...
# 82661               data scientist    1.0  1800000.0           NaN  1800000.0
# 100656      engineering leadership    1.0  2500000.0           NaN  2500000.0
# 50156           frontend developer    1.0  2400000.0           NaN  2400000.0
# 2791                        others    2.0  1525000.0  530330.08589  1150000.0
# 94157                       others    2.0  1525000.0  530330.08589  1150000.0
#
#               25%        50%        75%        max
# 46958    500000.0   500000.0   500000.0   500000.0
# 20396    500000.0   500000.0   500000.0   500000.0
# 2800     380000.0   380000.0   380000.0   380000.0
# 39108   1290000.0  1290000.0  1290000.0  1290000.0
# 24075    360000.0   360000.0   360000.0   360000.0
# ...           ...        ...        ...        ...
# 82661   1800000.0  1800000.0  1800000.0  1800000.0
# 100656  2500000.0  2500000.0  2500000.0  2500000.0
# 50156   2400000.0  2400000.0  2400000.0  2400000.0
# 2791    1337500.0  1525000.0  1712500.0  1900000.0
# 94157   1337500.0  1525000.0  1712500.0  1900000.0
#
# [112824 rows x 14 columns]

# %%
df_cj.shape
# Out:
# (112824, 14)

# %%
df_cj.drop_duplicates(inplace=True)

# %%
df_cj.shape
# Out:
# (112824, 14)

# %% [markdown]
# ### Creating Class basis on the salary they are getting in their respective company

# %%
def condition_classs(a,b_50,b_75):
    if a<b_50:
        return 3
    elif a>=b_50 and a<=b_75:
        return 2

    elif a>=b_75:
        return 1

# %%
df_cj['classs'] =df_cj.apply(lambda x: condition_classs(x['ctc'],x['50%'],x['75%']),axis=1)

# %%
df_cj
# Out:
#                      company_hash  orgyear      ctc  ctc_updated_year  \
# 0                  czniswwz sucsk   2016.0  1100000            2020.0
# 1       oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                          Others   2015.0  2000000            2020.0
# 3                       wirijzcsk   2017.0   700000            2019.0
# 4                      osbw toidj   2017.0  1400000            2019.0
# ...                           ...      ...      ...               ...
# 112819                     ioklnz   2019.0   950000            2021.0
# 112820            jinslagkqkkolih   2021.0  1000000            2021.0
# 112821          lft suwzoukwsiukn   2016.0  1500000            2021.0
# 112822                  cduuedhga   2019.0  1100000            2021.0
# 112823                     Others   2017.0  1100000            2021.0
#
#         years_of_experience        job_position   count          mean  \
# 0                       6.0              others     2.0  1.085000e+06
# 1                       4.0  fullstack devloper    25.0  9.882000e+05
# 2                       7.0    backend engineer  3871.0  1.001007e+06
# 3                       5.0    backend engineer    24.0  1.416667e+06
# 4                       5.0  fullstack devloper     3.0  8.466667e+05
# ...                     ...                 ...     ...           ...
# 112819                  3.0    backend engineer   633.0  1.447947e+06
# 112820                  1.0    backend engineer    16.0  1.089375e+06
# 112821                  6.0  fullstack devloper     7.0  1.481429e+06
# 112822                  3.0      data scientist    26.0  1.214154e+06
# 112823                  5.0  frontend developer  1809.0  8.950238e+05
#
#                   std        min         25%        50%        75%        max  \
# 0        21213.203436  1070000.0  1077500.00  1085000.0  1092500.0  1100000.0
# 1       487499.789590   300000.0   600000.00   850000.0  1380000.0  2000000.0
# 2       812465.827695     1000.0   300000.00   830000.0  1530000.0  3300000.0
# 3       545341.270627   520000.0  1047500.00  1375000.0  1792500.0  2600000.0
# 4       480138.868801   540000.0   570000.00   600000.0  1000000.0  1400000.0
# ...               ...        ...         ...        ...        ...        ...
# 112819  702632.095190     7500.0   950000.00  1300000.0  1900000.0  3300000.0
# 112820  519249.085299   330000.0   819999.25   965000.0  1325000.0  2500000.0
# 112821  659353.940648   550000.0  1050000.00  1500000.0  1860000.0  2500000.0
# 112822  448166.994975    31000.0  1025000.00  1195000.0  1400000.0  2000000.0
# 112823  649888.886024     1000.0   400000.00   810000.0  1240000.0  3300000.0
#
#         classs
# 0            1
# 1            3
# 2            1
# 3            3
# 4            1
# ...        ...
# 112819       3
# 112820       2
# 112821       2
# 112822       3
# 112823       2
#
# [112824 rows x 15 columns]

# %%
df_cj.classs.value_counts(normalize=True)*100
# Out:
# 3    43.105190
# 2    32.567539
# 1    24.327271
# Name: classs, dtype: float64

# %%
#insight

# %%
# job position that has the highest class
df_cj[df_cj['classs']==1][['job_position','ctc']].groupby('job_position')['ctc'].describe().sort_values(by=['count','mean'],ascending=False)[:10]
# Out:
#                          count          mean            std       min  \
# job_position
# backend engineer        8141.0  2.062922e+06  687453.523906   30000.0
# fullstack devloper      4738.0  1.843818e+06  688740.772724   59000.0
# others                  3252.0  1.631203e+06  703559.837379   72000.0
# frontend developer      2001.0  1.668149e+06  631746.759730   90000.0
# qa engineer             1264.0  1.393021e+06  629618.259158   65000.0
# data scientist          1014.0  2.004372e+06  657171.138374  115000.0
# software developer 1     994.0  1.555315e+06  719455.972181  140000.0
# devops engineer          927.0  1.750345e+06  626199.257910  400000.0
# android engineer         913.0  1.784897e+06  638704.770985   14000.0
# engineering leadership   780.0  2.544358e+06  584769.872493  124000.0
#
#                               25%        50%        75%        max
# job_position
# backend engineer        1550000.0  2000000.0  2600000.0  3330000.0
# fullstack devloper      1350000.0  1750000.0  2360000.0  3330000.0
# others                  1050000.0  1500000.0  2100000.0  3300000.0
# frontend developer      1210000.0  1550000.0  2030000.0  3300000.0
# qa engineer              900000.0  1250000.0  1707500.0  3300000.0
# data scientist          1600000.0  2000000.0  2500000.0  3310000.0
# software developer 1     900000.0  1450000.0  2000000.0  3329999.0
# devops engineer         1300000.0  1670000.0  2137500.0  3300000.0
# android engineer        1320000.0  1700000.0  2200000.0  3300000.0
# engineering leadership  2292500.0  2650000.0  3000000.0  3320000.0

# %%
#########
df_cjy.head()
# Out:
#                 company_hash  orgyear      ctc  ctc_updated_year  \
# 0             czniswwz sucsk   2016.0  1100000            2020.0
# 1  oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                     Others   2015.0  2000000            2020.0
# 3                  wirijzcsk   2017.0   700000            2019.0
# 4                 osbw toidj   2017.0  1400000            2019.0
#
#    years_of_experience        job_position  count          mean  \
# 0                  6.0              others    1.0  1.100000e+06
# 1                  4.0  fullstack devloper    7.0  7.742856e+05
# 2                  7.0    backend engineer  456.0  9.609559e+05
# 3                  5.0    backend engineer    7.0  1.158571e+06
# 4                  5.0  fullstack devloper    1.0  1.400000e+06
#
#              std        min        25%        50%        75%        max  \
# 0            NaN  1100000.0  1100000.0  1100000.0  1100000.0  1100000.0
# 1  250922.324350   449999.0   610000.0   750000.0   900000.0  1200000.0
# 2  776546.830662     1000.0   307500.0   800000.0  1435000.0  3200000.0
# 3  404780.951933   700000.0   825000.0  1200000.0  1405000.0  1750000.0
# 4            NaN  1400000.0  1400000.0  1400000.0  1400000.0  1400000.0
#
#    designation
# 0            2
# 1            3
# 2            1
# 3            3
# 4            2

# %%
df_cj.head()
# Out:
#                 company_hash  orgyear      ctc  ctc_updated_year  \
# 0             czniswwz sucsk   2016.0  1100000            2020.0
# 1  oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                     Others   2015.0  2000000            2020.0
# 3                  wirijzcsk   2017.0   700000            2019.0
# 4                 osbw toidj   2017.0  1400000            2019.0
#
#    years_of_experience        job_position   count          mean  \
# 0                  6.0              others     2.0  1.085000e+06
# 1                  4.0  fullstack devloper    25.0  9.882000e+05
# 2                  7.0    backend engineer  3871.0  1.001007e+06
# 3                  5.0    backend engineer    24.0  1.416667e+06
# 4                  5.0  fullstack devloper     3.0  8.466667e+05
#
#              std        min        25%        50%        75%        max  \
# 0   21213.203436  1070000.0  1077500.0  1085000.0  1092500.0  1100000.0
# 1  487499.789590   300000.0   600000.0   850000.0  1380000.0  2000000.0
# 2  812465.827695     1000.0   300000.0   830000.0  1530000.0  3300000.0
# 3  545341.270627   520000.0  1047500.0  1375000.0  1792500.0  2600000.0
# 4  480138.868801   540000.0   570000.0   600000.0  1000000.0  1400000.0
#
#    classs
# 0       1
# 1       3
# 2       1
# 3       3
# 4       1

# %%
df_cj.shape
# Out:
# (112824, 15)

# %%
df_cjy.shape
# Out:
# (112824, 15)

# %%
df_cj.drop(columns=['count','mean','std','min','25%','50%','75%','max'],inplace=True)
df_cjy.drop(columns=['count','mean','std','min','25%','50%','75%','max'],inplace=True)

# %%
df_cj.drop_duplicates().shape
# Out:
# (112824, 7)

# %%
df_cjy.drop_duplicates().shape
# Out:
# (112824, 7)

# %%
df_cjy_cj=df_cj.merge(df_cjy, on=['company_hash','orgyear','ctc','job_position','years_of_experience','ctc_updated_year'], how='left')

# %%
df_cjy_cj.shape
# Out:
# (112824, 8)

# %%
df_cjy_cj.drop_duplicates().shape
# Out:
# (112824, 8)

# %%
#verify if the join is right or now

# %% [markdown]
# ## Manual Clustering based on comapny

# %%
grouped_c=df.groupby(['company_hash'])['ctc'].describe()

# %%
df_c=df.merge(grouped_c, on=['company_hash'], how='left')

# %%
df_c.head(5)
# Out:
#                 company_hash  orgyear      ctc  ctc_updated_year  \
# 0             czniswwz sucsk   2016.0  1100000            2020.0
# 1  oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                     Others   2015.0  2000000            2020.0
# 3                  wirijzcsk   2017.0   700000            2019.0
# 4                 osbw toidj   2017.0  1400000            2019.0
#
#    years_of_experience        job_position    count          mean  \
# 0                  6.0              others      9.0  1.115667e+06
# 1                  4.0  fullstack devloper    293.0  1.067873e+06
# 2                  7.0    backend engineer  21213.0  9.600989e+05
# 3                  5.0    backend engineer     45.0  1.385444e+06
# 4                  5.0  fullstack devloper      5.0  9.880000e+05
#
#              std       min        25%        50%        75%        max
# 0  458111.885897  500000.0   800000.0  1070000.0  1500000.0  1771000.0
# 1  644402.951971   10000.0   600000.0   880000.0  1500000.0  3200000.0
# 2  750047.695406      24.0   400000.0   800000.0  1400000.0  3329999.0
# 3  564289.398494  200000.0  1050000.0  1300000.0  1790000.0  2600000.0
# 4  415595.957632  540000.0   600000.0  1000000.0  1400000.0  1400000.0

# %%
#verify
df_c.sort_values(['company_hash'])
# Out:
#        company_hash  orgyear      ctc  ctc_updated_year  years_of_experience  \
# 112823       Others   2017.0  1100000            2021.0                  5.0
# 54584        Others   2011.0   660000            2019.0                 11.0
# 16131        Others   2018.0   640000            2020.0                  4.0
# 54585        Others   2014.0  1250000            2019.0                  8.0
# 54600        Others   2014.0   480000            2019.0                  8.0
# ...             ...      ...      ...               ...                  ...
# 50156    zyyiuhigsn   2011.0  2400000            2019.0                 11.0
# 2791     zyyiuhigsn   2018.0  1900000            2021.0                  4.0
# 16226    zyyiuhigsn   2018.0    80000            2020.0                  4.0
# 83334    zyyiuhigsn   2012.0  2700000            2021.0                 10.0
# 82661    zyyiuhigsn   2012.0  1800000            2019.0                 10.0
#
#               job_position    count          mean            std      min  \
# 112823  frontend developer  21213.0  9.600989e+05  750047.695406     24.0
# 54584   fullstack devloper  21213.0  9.600989e+05  750047.695406     24.0
# 16131   frontend developer  21213.0  9.600989e+05  750047.695406     24.0
# 54585     android engineer  21213.0  9.600989e+05  750047.695406     24.0
# 54600     android engineer  21213.0  9.600989e+05  750047.695406     24.0
# ...                    ...      ...           ...            ...      ...
# 50156   frontend developer      8.0  1.803750e+06  850276.215625  80000.0
# 2791                others      8.0  1.803750e+06  850276.215625  80000.0
# 16226     backend engineer      8.0  1.803750e+06  850276.215625  80000.0
# 83334     backend engineer      8.0  1.803750e+06  850276.215625  80000.0
# 82661       data scientist      8.0  1.803750e+06  850276.215625  80000.0
#
#               25%        50%        75%        max
# 112823   400000.0   800000.0  1400000.0  3329999.0
# 54584    400000.0   800000.0  1400000.0  3329999.0
# 16131    400000.0   800000.0  1400000.0  3329999.0
# 54585    400000.0   800000.0  1400000.0  3329999.0
# 54600    400000.0   800000.0  1400000.0  3329999.0
# ...           ...        ...        ...        ...
# 50156   1637500.0  1900000.0  2425000.0  2700000.0
# 2791    1637500.0  1900000.0  2425000.0  2700000.0
# 16226   1637500.0  1900000.0  2425000.0  2700000.0
# 83334   1637500.0  1900000.0  2425000.0  2700000.0
# 82661   1637500.0  1900000.0  2425000.0  2700000.0
#
# [112824 rows x 14 columns]

# %%
print(df.drop_duplicates().shape)
print(df_c.shape)
print(df_c.drop_duplicates().shape)
# Out:
# (112824, 6)
# (112824, 14)
# (112824, 14)

# %% [markdown]
# ### Creating Tier basis on the salary in the companies

# %%
def condition_tier(a,b_50,b_75):
    if a<b_50:
        return 3
    elif a>=b_50 and a<=b_75:
        return 2

    elif a>=b_75:
        return 1

# %%
df_c['tier'] =df_c.apply(lambda x: condition_tier(x['ctc'],x['50%'],x['75%']),axis=1)

# %%
df_c.head()
# Out:
#                 company_hash  orgyear      ctc  ctc_updated_year  \
# 0             czniswwz sucsk   2016.0  1100000            2020.0
# 1  oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                     Others   2015.0  2000000            2020.0
# 3                  wirijzcsk   2017.0   700000            2019.0
# 4                 osbw toidj   2017.0  1400000            2019.0
#
#    years_of_experience        job_position    count          mean  \
# 0                  6.0              others      9.0  1.115667e+06
# 1                  4.0  fullstack devloper    293.0  1.067873e+06
# 2                  7.0    backend engineer  21213.0  9.600989e+05
# 3                  5.0    backend engineer     45.0  1.385444e+06
# 4                  5.0  fullstack devloper      5.0  9.880000e+05
#
#              std       min        25%        50%        75%        max  tier
# 0  458111.885897  500000.0   800000.0  1070000.0  1500000.0  1771000.0     2
# 1  644402.951971   10000.0   600000.0   880000.0  1500000.0  3200000.0     3
# 2  750047.695406      24.0   400000.0   800000.0  1400000.0  3329999.0     1
# 3  564289.398494  200000.0  1050000.0  1300000.0  1790000.0  2600000.0     3
# 4  415595.957632  540000.0   600000.0  1000000.0  1400000.0  1400000.0     2

# %%
df_c.tier.value_counts(normalize=True)*100
# Out:
# 3    47.899383
# 2    28.177515
# 1    23.923101
# Name: tier, dtype: float64

# %%
df_cjy_cj_c=df_cjy_cj.merge(df_c, on=['company_hash','orgyear','ctc','job_position','years_of_experience','ctc_updated_year'], how='left')

# %%
df_cjy_cj_c.head(10)
# Out:
#                           company_hash  orgyear      ctc  ctc_updated_year  \
# 0                       czniswwz sucsk   2016.0  1100000            2020.0
# 1            oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                               Others   2015.0  2000000            2020.0
# 3                            wirijzcsk   2017.0   700000            2019.0
# 4                           osbw toidj   2017.0  1400000            2019.0
# 5  ekjjsna duhkooszc hkorzwsut jvw nwc   2018.0   700000            2020.0
# 6                   pjhiotku lekfz  li   2018.0  1500000            2019.0
# 7                 kllzuwdoz wzleuinita   2019.0   400000            2019.0
# 8                      uzmtzu fibwmkoz   2019.0   420000            2020.0
# 9                               Others   2016.0   600000            2021.0
#
#    years_of_experience        job_position  classs  designation    count  \
# 0                  6.0              others       1            2      9.0
# 1                  4.0  fullstack devloper       3            3    293.0
# 2                  7.0    backend engineer       1            1  21213.0
# 3                  5.0    backend engineer       3            3     45.0
# 4                  5.0  fullstack devloper       1            2      5.0
# 5                  4.0  fullstack devloper       2            2      6.0
# 6                  4.0  fullstack devloper       3            3    662.0
# 7                  3.0    backend engineer       3            3     14.0
# 8                  3.0  fullstack devloper       3            3    215.0
# 9                  6.0        ios engineer       3            3  21213.0
#
#            mean            std       min        25%        50%        75%  \
# 0  1.115667e+06  458111.885897  500000.0   800000.0  1070000.0  1500000.0
# 1  1.067873e+06  644402.951971   10000.0   600000.0   880000.0  1500000.0
# 2  9.600989e+05  750047.695406      24.0   400000.0   800000.0  1400000.0
# 3  1.385444e+06  564289.398494  200000.0  1050000.0  1300000.0  1790000.0
# 4  9.880000e+05  415595.957632  540000.0   600000.0  1000000.0  1400000.0
# 5  9.066667e+05  539728.326722  620000.0   640000.0   700000.0   775000.0
# 6  1.712295e+06  677124.221498   11000.0  1300000.0  1685000.0  2127500.0
# 7  6.864286e+05  307286.064238  300000.0   412500.0   620000.0   910000.0
# 8  6.701256e+05  321893.320045    5500.0   480000.0   600000.0   755000.0
# 9  9.600989e+05  750047.695406      24.0   400000.0   800000.0  1400000.0
#
#          max  tier
# 0  1771000.0     2
# 1  3200000.0     3
# 2  3329999.0     1
# 3  2600000.0     3
# 4  1400000.0     2
# 5  2000000.0     2
# 6  3300000.0     3
# 7  1150000.0     3
# 8  2000000.0     3
# 9  3329999.0     3

# %%
df_cjy_cj_c.shape
# Out:
# (112824, 17)

# %%
data=df_cjy_cj_c.copy(deep=True)

# %%
data.drop(columns=['count','mean','std','min','25%','50%','75%','max'],inplace=True)

# %%
data.shape
# Out:
# (112824, 9)

# %%
data
# Out:
#                      company_hash  orgyear      ctc  ctc_updated_year  \
# 0                  czniswwz sucsk   2016.0  1100000            2020.0
# 1       oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                          Others   2015.0  2000000            2020.0
# 3                       wirijzcsk   2017.0   700000            2019.0
# 4                      osbw toidj   2017.0  1400000            2019.0
# ...                           ...      ...      ...               ...
# 112819                     ioklnz   2019.0   950000            2021.0
# 112820            jinslagkqkkolih   2021.0  1000000            2021.0
# 112821          lft suwzoukwsiukn   2016.0  1500000            2021.0
# 112822                  cduuedhga   2019.0  1100000            2021.0
# 112823                     Others   2017.0  1100000            2021.0
#
#         years_of_experience        job_position  classs  designation  tier
# 0                       6.0              others       1            2     2
# 1                       4.0  fullstack devloper       3            3     3
# 2                       7.0    backend engineer       1            1     1
# 3                       5.0    backend engineer       3            3     3
# 4                       5.0  fullstack devloper       1            2     2
# ...                     ...                 ...     ...          ...   ...
# 112819                  3.0    backend engineer       3            3     3
# 112820                  1.0    backend engineer       2            2     2
# 112821                  6.0  fullstack devloper       2            1     1
# 112822                  3.0      data scientist       3            1     3
# 112823                  5.0  frontend developer       2            1     2
#
# [112824 rows x 9 columns]

# %% [markdown]
# # Some more joins and cluster analysis steps (Optional 1)

# %%
company_cluster_n=grouped_c.sort_values(by=['50%','count'], ascending=False).reset_index()
# can check this with less standard deviation

# %%
company_cluster_n
# Out:
#              company_hash  count          mean           std        min  \
# 0        igfzovzks q nkgf    2.0  3.150000e+06  2.121320e+05  3000000.0
# 1               suczzclih    9.0  1.999444e+06  1.418891e+06   140000.0
# 2               ekouzffsi    5.0  2.864000e+06  3.622568e+05  2320000.0
# 3                harkkohk   11.0  2.545455e+06  5.561180e+05  1400000.0
# 4                 kukoilr    6.0  2.600000e+06  7.211103e+05  1400000.0
# ...                   ...    ...           ...           ...        ...
# 2910                zpkck   13.0  1.918000e+05  2.752249e+05     6000.0
# 2911                 lzou    7.0  2.478571e+05  5.081081e+05    45000.0
# 2912               akuczy   13.0  2.071538e+05  5.393918e+05    20000.0
# 2913           kualiuuzlw    8.0  2.325000e+05  3.901666e+05     7000.0
# 2914  sjvsfsiu lkukck sul    5.0  6.392000e+05  8.381952e+05    24000.0
#
#             25%        50%        75%        max
# 0     3075000.0  3150000.0  3225000.0  3300000.0
# 1      200000.0  3000000.0  3010000.0  3300000.0
# 2     2750000.0  2950000.0  3000000.0  3300000.0
# 3     2100000.0  2900000.0  2900000.0  3070000.0
# 4     2250000.0  2850000.0  3075000.0  3300000.0
# ...         ...        ...        ...        ...
# 2910    28000.0    60000.0   150000.0   900000.0
# 2911    50000.0    60000.0    65000.0  1400000.0
# 2912    40000.0    57000.0    85000.0  2000000.0
# 2913     7000.0    38500.0   221500.0  1000000.0
# 2914    36000.0    36000.0  1400000.0  1700000.0
#
# [2915 rows x 9 columns]

# %%
diff=((company_cluster_n['50%'][0:1].values -company_cluster_n['50%'][-1:].values)/3)[0]
diff
# Out:
# 1038000.0

# %%
(company_cluster_n['50%'][0:1].values - diff)[0]
# Out:
# 2112000.0

# %%
company_cluster_n.loc[company_cluster_n['50%']>=(company_cluster_n['50%'][0:1].values - diff)[0],'company_cluster_n']=1


company_cluster_n.loc[(company_cluster_n['50%']<(company_cluster_n['50%'][0:1].values - diff)[0])
                      &
                      (company_cluster_n['50%']>=(company_cluster_n['50%'][0:1].values - 2*diff)[0])


                      ,'company_cluster_n']=2

company_cluster_n['company_cluster_n'].fillna(3,inplace=True)

# %%
company_cluster_n['company_cluster_n'].value_counts(normalize=True)*100
# Out:
# 3.0    57.255575
# 2.0    39.691252
# 1.0     3.053173
# Name: company_cluster_n, dtype: float64

# %%
####

# %%
company_job_cluster_n=grouped_c_j.sort_values(by=['50%','count'], ascending=False).reset_index() # can check this with less standard deviation

# %%
company_job_cluster_n
# Out:
#                  job_position                   company_hash  count  \
# 0      engineering leadership                gzlrhku lidnwzo    1.0
# 1            product designer                      wkwk lnsx    1.0
# 2          frontend developer  liniowirzuf nnj sucsk jvw nwc    1.0
# 3             product manager                  hkrzhawosjlih    3.0
# 4                 qa engineer                     tipzr wzle    2.0
# ...                       ...                            ...    ...
# 18528         devops engineer               msjoi nwc  sucsk    1.0
# 18529                  others                         nirwok    1.0
# 18530    technical consultant         uiw kjjnslkgnz klliduw    1.0
# 18531        android engineer                    vsf lkozzof    1.0
# 18532            ios engineer                        fwkowdj    1.0
#
#             mean            std        min        25%        50%        75%  \
# 0      3329999.0            NaN  3329999.0  3329999.0  3329999.0  3329999.0
# 1      3329999.0            NaN  3329999.0  3329999.0  3329999.0  3329999.0
# 2      3325000.0            NaN  3325000.0  3325000.0  3325000.0  3325000.0
# 3      3200000.0  173205.080757  3000000.0  3150000.0  3300000.0  3300000.0
# 4      3300000.0       0.000000  3300000.0  3300000.0  3300000.0  3300000.0
# ...          ...            ...        ...        ...        ...        ...
# 18528     4000.0            NaN     4000.0     4000.0     4000.0     4000.0
# 18529     4000.0            NaN     4000.0     4000.0     4000.0     4000.0
# 18530     2000.0            NaN     2000.0     2000.0     2000.0     2000.0
# 18531     1000.0            NaN     1000.0     1000.0     1000.0     1000.0
# 18532     1000.0            NaN     1000.0     1000.0     1000.0     1000.0
#
#              max
# 0      3329999.0
# 1      3329999.0
# 2      3325000.0
# 3      3300000.0
# 4      3300000.0
# ...          ...
# 18528     4000.0
# 18529     4000.0
# 18530     2000.0
# 18531     1000.0
# 18532     1000.0
#
# [18533 rows x 10 columns]

# %%
diff=((company_job_cluster_n['50%'][0:1].values -company_job_cluster_n['50%'][-1:].values)/3)[0]
diff
# Out:
# 1109666.3333333333

# %%
company_job_cluster_n.loc[company_job_cluster_n['50%']>=(company_job_cluster_n['50%'][0:1].values - diff)[0],'company_job_cluster_n']=1


company_job_cluster_n.loc[(company_job_cluster_n['50%']<(company_job_cluster_n['50%'][0:1].values - diff)[0])
                      &
                      (company_job_cluster_n['50%']>=(company_job_cluster_n['50%'][0:1].values - 2*diff)[0])


                      ,'company_job_cluster_n']=2

company_job_cluster_n['company_job_cluster_n'].fillna(3,inplace=True)

# %%
company_job_cluster_n['company_job_cluster_n'].value_counts()
# Out:
# 3.0    10633
# 2.0     6379
# 1.0     1521
# Name: company_job_cluster_n, dtype: int64

# %% [markdown]
# ## Merging data with these two generated columns

# %%
data_company_n=data.merge(company_cluster_n, on ='company_hash', how='left')

# %%
x=list(data.columns)
x.append('company_cluster_n')
data_company_n=data_company_n[x]

# %%
company_job_cluster_n
# Out:
#                  job_position                   company_hash  count  \
# 0      engineering leadership                gzlrhku lidnwzo    1.0
# 1            product designer                      wkwk lnsx    1.0
# 2          frontend developer  liniowirzuf nnj sucsk jvw nwc    1.0
# 3             product manager                  hkrzhawosjlih    3.0
# 4                 qa engineer                     tipzr wzle    2.0
# ...                       ...                            ...    ...
# 18528         devops engineer               msjoi nwc  sucsk    1.0
# 18529                  others                         nirwok    1.0
# 18530    technical consultant         uiw kjjnslkgnz klliduw    1.0
# 18531        android engineer                    vsf lkozzof    1.0
# 18532            ios engineer                        fwkowdj    1.0
#
#             mean            std        min        25%        50%        75%  \
# 0      3329999.0            NaN  3329999.0  3329999.0  3329999.0  3329999.0
# 1      3329999.0            NaN  3329999.0  3329999.0  3329999.0  3329999.0
# 2      3325000.0            NaN  3325000.0  3325000.0  3325000.0  3325000.0
# 3      3200000.0  173205.080757  3000000.0  3150000.0  3300000.0  3300000.0
# 4      3300000.0       0.000000  3300000.0  3300000.0  3300000.0  3300000.0
# ...          ...            ...        ...        ...        ...        ...
# 18528     4000.0            NaN     4000.0     4000.0     4000.0     4000.0
# 18529     4000.0            NaN     4000.0     4000.0     4000.0     4000.0
# 18530     2000.0            NaN     2000.0     2000.0     2000.0     2000.0
# 18531     1000.0            NaN     1000.0     1000.0     1000.0     1000.0
# 18532     1000.0            NaN     1000.0     1000.0     1000.0     1000.0
#
#              max  company_job_cluster_n
# 0      3329999.0                    1.0
# 1      3329999.0                    1.0
# 2      3325000.0                    1.0
# 3      3300000.0                    1.0
# 4      3300000.0                    1.0
# ...          ...                    ...
# 18528     4000.0                    3.0
# 18529     4000.0                    3.0
# 18530     2000.0                    3.0
# 18531     1000.0                    3.0
# 18532     1000.0                    3.0
#
# [18533 rows x 11 columns]

# %%
final_n=data_company_n.merge(company_job_cluster_n, on =['company_hash','job_position'], how='left')

# %%
y=list(data_company_n.columns)
y.append('company_job_cluster_n')
final_n=final_n[y]

# %%
#used this step if we are not doing the option 2
final=final_n.copy()

# %%
final
# Out:
#                      company_hash  orgyear      ctc  ctc_updated_year  \
# 0                  czniswwz sucsk   2016.0  1100000            2020.0
# 1       oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                          Others   2015.0  2000000            2020.0
# 3                       wirijzcsk   2017.0   700000            2019.0
# 4                      osbw toidj   2017.0  1400000            2019.0
# ...                           ...      ...      ...               ...
# 112819                     ioklnz   2019.0   950000            2021.0
# 112820            jinslagkqkkolih   2021.0  1000000            2021.0
# 112821          lft suwzoukwsiukn   2016.0  1500000            2021.0
# 112822                  cduuedhga   2019.0  1100000            2021.0
# 112823                     Others   2017.0  1100000            2021.0
#
#         years_of_experience        job_position  classs  designation  tier  \
# 0                       6.0              others       1            2     2
# 1                       4.0  fullstack devloper       3            3     3
# 2                       7.0    backend engineer       1            1     1
# 3                       5.0    backend engineer       3            3     3
# 4                       5.0  fullstack devloper       1            2     2
# ...                     ...                 ...     ...          ...   ...
# 112819                  3.0    backend engineer       3            3     3
# 112820                  1.0    backend engineer       2            2     2
# 112821                  6.0  fullstack devloper       2            1     1
# 112822                  3.0      data scientist       3            1     3
# 112823                  5.0  frontend developer       2            1     2
#
#         company_cluster_n  company_job_cluster_n
# 0                     3.0                    3.0
# 1                     3.0                    3.0
# 2                     3.0                    3.0
# 3                     2.0                    2.0
# 4                     3.0                    3.0
# ...                   ...                    ...
# 112819                2.0                    2.0
# 112820                3.0                    3.0
# 112821                3.0                    2.0
# 112822                2.0                    2.0
# 112823                3.0                    3.0
#
# [112824 rows x 11 columns]

# %% [markdown]
# # Some more joins and cluster analysis steps (Optional 2)
#
# company_cluster=grouped_c.sort_values(by=['50%','count'], ascending=False).reset_index().reset_index() # can check this with less standard deviation
#
# company_cluster
#
# company_cluster.shape
#
# company_cluster.loc[company_cluster['index']<=round(company_cluster.shape[0]/3),'company_cluster']=1
# company_cluster.loc[(company_cluster['index']>round(company_cluster.shape[0]/3))
#                     &
#                     (company_cluster['index']<=round(2*company_cluster.shape[0]/3))
#                     ,'company_cluster']=2
#
# company_cluster.loc[(company_cluster['index']>round(2*company_cluster.shape[0]/3))
#                     ,'company_cluster']=3
#
# company_cluster['company_cluster'].value_counts()
#
# company_job_cluster=grouped_c_j.sort_values(by=['50%','count'], ascending=False).reset_index().reset_index() # can check this with less standard deviation
#
# company_job_cluster
#
# company_job_cluster.shape
#
# company_job_cluster.loc[company_job_cluster['index']<=round(company_job_cluster.shape[0]/3),'company_job_cluster']=1
# company_job_cluster.loc[(company_job_cluster['index']>round(company_job_cluster.shape[0]/3))
#                     &
#                     (company_job_cluster['index']<=round(2*company_job_cluster.shape[0]/3))
#                     ,'company_job_cluster']=2
#
# company_job_cluster.loc[(company_job_cluster['index']>round(2*company_job_cluster.shape[0]/3))
#                     ,'company_job_cluster']=3
#
# company_job_cluster['company_job_cluster'].value_counts()
#
# ## Merging data with these two generated columns
#
# data_company=data.merge(company_cluster, on ='company', how='left')
#
# x=list(data.columns)
#
# x.append('company_cluster')
#
# data_company=data_company[x]
#
# final=data_company.merge(company_job_cluster, on =['company','job_position'], how='left')
#
# y=list(data_company.columns)
# y.append('company_job_cluster')
# final=final[y]

# %% [markdown]
# ### Definition:
#
# 1. **Designation**: Salary an employee is getting wrt salary in the same Company, Job_Position & Years of Experience
# 2. **Class**: Salary an employee is getting wrt the salary in the same Company & Job_Position
# 3. **Tier**: Salary an employee is getting wrt the salary in the same Company
#
#
# ![image.png](attachment:image.png)
# ### Some Questions this data can Answer: <br>
#     1. Show creme de la creme records from the data (Filter 1 from all the flags)
#     2. What's the current positioning of the employee
#     3. Where to next? Pitch (After seeing their present cluster)

# %% [markdown]
# ## Macro Analysis Ex:
# Since we are doing clustering at employee level we have to bring characterics of employees only.
# 1. Top 10 employees (earning more than most of the employees in the company) (tier 1) <br>
#
#     1a. Top 10 employees of data science in Amazon / TCS etc earning more than their peers (class 1) <br>
#     1b. Bottom 10 employees of data science in Amazon / TCS etc earning less than their peers (class 3) <br>
# 2. Bottom 10 employees (earning less than most of the employees in the company) (tier 3)
# 3. Top 10 employees in the amazon- data science- having 5/6/7 years of experience earning more than their peers
#
# ## Micro Analysis Examples:
# 1. Top 10 companies (basis on their offered CTC) - grouped_c, sort by descending, head(10)
# 2. Top 2 positions in every company (basis on their offered CTC) - grouped_c_j, sort by descending, head(10)

# %%
x=final.copy()

# %%
final.shape
# Out:
# (112824, 11)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112824 entries, 0 to 112823
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   company_hash           112824 non-null  object
#  1   orgyear                112824 non-null  float64
#  2   ctc                    112824 non-null  int64
#  3   ctc_updated_year       112824 non-null  float64
#  4   years_of_experience    112824 non-null  float64
#  5   job_position           112824 non-null  object
#  6   classs                 112824 non-null  int64
#  7   designation            112824 non-null  int64
#  8   tier                   112824 non-null  int64
#  9   company_cluster_n      112824 non-null  float64
#  10  company_job_cluster_n  112824 non-null  float64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 10.3+ MB

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## KMeans

# %% [markdown]
# 1. Check Clustering Tendency
# 2. Do elbow method etc for checking the number of optimal clusters (bring it to 3)
# 3. Do kmeans clustering
# 4. Hierarchial clustering of sample dataset (shuffle and take 50k rows)

# %% [markdown]
# ## Label encoding

# %%
x.shape
# Out:
# (112824, 11)

# %%
x['company_hash'].unique()
# Out:
# array(['czniswwz sucsk', 'oznskulz subilihh nshswzc', 'Others', ...,
#        'fknwfscz', 'eajzovzotz sul', 'bkkfif'], dtype=object)

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
x['company_hash']= label_encoder.fit_transform(x['company_hash'])

x['company_hash'].unique()
# Out:
# array([ 194, 1846,    0, ...,  503,  250,   43])

# %%
x['job_position']= label_encoder.fit_transform(x['job_position'])
x['job_position'].unique()
# Out:
# array([273, 178,  86, 206, 124, 176, 154, 128, 153,  16, 314, 331, 420,
#        492, 349, 143, 296, 304, 110, 293, 494,  85, 132, 327,  27, 535,
#         51,   3, 446, 531, 363, 310, 248, 432, 145,  20,  92, 358, 180,
#        239, 439, 198, 488, 269, 367, 202, 362, 264,  64, 517, 161,  42,
#        440, 163,  47, 292, 449,  45, 426, 201, 294, 152, 466, 157,  58,
#        179, 433, 387, 225,  93, 441, 365, 200,  90,  48, 215, 532, 339,
#        231, 551, 309, 237,  11, 381,  75, 343, 252, 385, 306, 509, 251,
#        451, 500,  66, 543, 516, 370, 164,  87, 335, 397, 295, 101, 361,
#        342, 357, 285, 319, 444,  79, 312, 352, 135, 401,  65, 493, 513,
#         63, 191, 321, 233, 416, 540, 255, 396, 274, 276, 166, 262, 337,
#        328, 241, 423, 158, 368, 430, 224, 246, 541, 268, 108, 480,  99,
#        125, 369, 425,  60, 445, 398, 503, 187,  46, 545, 392,  55, 318,
#        113, 230, 307, 258, 100, 112,  41,  23, 226, 502, 499, 168, 120,
#        372,   4,  59, 148, 412, 409, 486, 244, 461, 278,  13, 139, 280,
#        384, 458, 468, 167, 320,  80,   2, 431, 138, 289, 236, 474, 150,
#        282,  37, 107, 427, 508,  54, 291, 421, 523, 475,  44, 496, 405,
#        257, 386, 477,  15, 238, 175, 106,   7,  96, 315,  77, 182, 109,
#         82,  81, 419, 341, 141, 380,  61, 171, 507,  19, 553,  32, 521,
#        265, 415, 322, 454, 436, 443, 266, 346, 442,  26, 259,  72, 422,
#        464, 382, 450, 121, 495,  21, 184, 491, 375, 190, 277,  24,  49,
#        338, 245, 210, 329, 218, 279,  36, 435, 116, 460,  18, 353, 147,
#         35,  34, 526, 406,  28,  14, 336, 240, 530, 548, 111, 383,  52,
#         68, 403, 283, 371, 537, 539, 249, 472, 169, 351, 129, 484,  39,
#        192, 528, 463, 288, 434, 323, 247, 311,  88,  71, 197, 533, 501,
#        330, 317, 481,   9, 479,  50, 117, 470, 542,  97, 471, 519, 400,
#        373, 544, 515,  31, 130, 407, 299, 133, 360, 497, 271, 469, 399,
#        549, 119, 547, 485,   5, 186, 165, 476, 256,  53, 155,   6, 122,
#         95,  74, 151, 173, 216, 115, 389, 418, 550,  98, 378, 359, 356,
#        462, 402, 391, 298,  22, 305, 189, 205, 195, 428, 221, 340,   1,
#        512, 207,   0, 228, 196,  70, 316, 232, 429, 290, 455, 281,  56,
#        333, 263, 326, 254,  94, 222, 235, 465, 212, 203, 185, 518, 137,
#        275, 160,  43, 114, 270,  17, 284, 162, 354, 498, 134, 156, 487,
#        377, 159,  62, 404, 131, 144, 525, 242, 260,  78, 552, 272, 243,
#        478, 308, 261, 514, 199, 395, 172, 355, 388,  25, 334,  89, 529,
#        146, 390, 413, 452, 140, 301, 522, 302, 511, 527, 408,  29, 303,
#        520, 348, 324, 313,  91, 149, 424,  76, 227, 104, 366, 536, 490,
#        459, 170, 193,  33, 417, 332, 350, 223, 183, 457, 505, 219, 118,
#         69, 379, 482, 214,  57, 250, 347,  84, 410, 136, 204, 102, 448,
#        538, 524,  73, 234, 127, 438,  38, 437, 374, 325, 211, 467, 208,
#        142,  67, 123, 267, 411, 489, 414, 345, 300, 103, 209, 506, 453,
#        364, 510, 287, 344, 105, 174, 126, 213,  30, 456, 181,  40, 220,
#        393, 229, 483, 394, 376, 188, 177,   8,  10, 286, 534, 194, 504,
#        217, 297, 447, 473,  12, 253, 546,  83])

# %% [markdown]
# x=pd.read_csv('suraajcln.csv',index_col=0)

# %%
x.head()
# Out:
#    company_hash  orgyear      ctc  ctc_updated_year  years_of_experience  \
# 0           194   2016.0  1100000            2020.0                  6.0
# 1          1846   2018.0   449999            2019.0                  4.0
# 2             0   2015.0  2000000            2020.0                  7.0
# 3          2596   2017.0   700000            2019.0                  5.0
# 4          1815   2017.0  1400000            2019.0                  5.0
#
#    job_position  classs  designation  tier  company_cluster_n  \
# 0           273       1            2     2                3.0
# 1           178       3            3     3                3.0
# 2            86       1            1     1                3.0
# 3            86       3            3     3                2.0
# 4           178       1            2     2                3.0
#
#    company_job_cluster_n
# 0                    3.0
# 1                    3.0
# 2                    3.0
# 3                    2.0
# 4                    3.0

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112824 entries, 0 to 112823
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   company_hash           112824 non-null  int64
#  1   orgyear                112824 non-null  float64
#  2   ctc                    112824 non-null  int64
#  3   ctc_updated_year       112824 non-null  float64
#  4   years_of_experience    112824 non-null  float64
#  5   job_position           112824 non-null  int64
#  6   classs                 112824 non-null  int64
#  7   designation            112824 non-null  int64
#  8   tier                   112824 non-null  int64
#  9   company_cluster_n      112824 non-null  float64
#  10  company_job_cluster_n  112824 non-null  float64
# dtypes: float64(5), int64(6)
# memory usage: 10.3 MB

# %%
x.drop(columns=['orgyear'],inplace=True)
x.drop(columns=['ctc_updated_year'],inplace=True)
#x.drop(columns=['job_position'],inplace=True)

# %%
x.head()
# Out:
#    company_hash      ctc  years_of_experience  job_position  classs  \
# 0           194  1100000                  6.0           273       1
# 1          1846   449999                  4.0           178       3
# 2             0  2000000                  7.0            86       1
# 3          2596   700000                  5.0            86       3
# 4          1815  1400000                  5.0           178       1
#
#    designation  tier  company_cluster_n  company_job_cluster_n
# 0            2     2                3.0                    3.0
# 1            3     3                3.0                    3.0
# 2            1     1                3.0                    3.0
# 3            3     3                2.0                    2.0
# 4            2     2                3.0                    3.0

# %%
x.isnull().sum()
# Out:
# company_hash             0
# ctc                      0
# years_of_experience      0
# job_position             0
# classs                   0
# designation              0
# tier                     0
# company_cluster_n        0
# company_job_cluster_n    0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
# ------- fix X #do this after label encoding
x[['ctc']] = ms.fit_transform(x[['ctc']])
print(x.head())
# Out:
#    company_hash       ctc  years_of_experience  job_position  classs  \
# 0           194  0.330330                  6.0           273       1
# 1          1846  0.135134                  4.0           178       3
# 2             0  0.600600                  7.0            86       1
# 3          2596  0.210210                  5.0            86       3
# 4          1815  0.420420                  5.0           178       1
#
#    designation  tier  company_cluster_n  company_job_cluster_n
# 0            2     2                3.0                    3.0
# 1            3     3                3.0                    3.0
# 2            1     1                3.0                    3.0
# 3            3     3                2.0                    2.0
# 4            2     2                3.0                    3.0

# %% [markdown]
# Clustering Tendancy

# %%
# !pip install pyclustertend
# Out:
# Requirement already satisfied: pyclustertend in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (1.7.0)
# Requirement already satisfied: pandas<2.0.0,>=1.2.0 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from pyclustertend) (1.3.4)
# Requirement already satisfied: numba<0.55.0,>=0.54.1 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from pyclustertend) (0.54.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.3 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from pyclustertend) (3.4.3)
# Requirement already satisfied: numpy==1.20.3 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from pyclustertend) (1.20.3)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.0 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from pyclustertend) (0.24.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->pyclustertend) (1.3.1)
# Requirement already satisfied: six in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib<4.0.0,>=3.3.3->pyclustertend) (1.16.0)
# Requirement already satisfied: setuptools in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from numba<0.55.0,>=0.54.1->pyclustertend) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from numba<0.55.0,>=0.54.1->pyclustertend) (0.37.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.2.0->pyclustertend) (2021.3)
# Requirement already satisfied: joblib>=0.11 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn<0.25.0,>=0.24.0->pyclustertend) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn<0.25.0,>=0.24.0->pyclustertend) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /Users/suraaj/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn<0.25.0,>=0.24.0->pyclustertend) (1.7.1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.cluster import KMeans
from pyclustertend import hopkins
from sklearn.preprocessing import scale

# %%
x.dropna(inplace=True)

# %%
hop=hopkins(x,150)

# %%
print(hop)
# Out:
# 0.0713676212871527

# %%
#o=x.copy(deep=True)

# %%
Sum_of_squared_distances = []
K = range(1,10)
for num_clusters in K :
  kmeans = KMeans(n_clusters=num_clusters)
  kmeans.fit(x)
  Sum_of_squared_distances.append(kmeans.inertia_)
plt.plot(K,Sum_of_squared_distances,'bx-')
plt.xlabel('Values of K')
plt.ylabel('Sum of squared distances/Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters=3)

kmeans.fit(x)
print(kmeans.cluster_centers_)
print(kmeans.cluster_centers_.shape)
# Out:
# [[2.35461006e+03 3.27852171e-01 6.42585253e+00 1.81470774e+02
#   2.17578125e+00 2.09315123e+00 2.23337705e+00 2.64601391e+00
#   2.62371693e+00]
#  [1.69934240e+02 3.29850398e-01 7.08094619e+00 1.78127286e+02
#   2.20643406e+00 2.15955056e+00 2.24596097e+00 2.71567120e+00
#   2.69712596e+00]
#  [1.24717313e+03 3.63444890e-01 6.66382445e+00 1.78511543e+02
#   2.17741072e+00 2.10045945e+00 2.23868986e+00 2.47799983e+00
#   2.49852017e+00]]
# (3, 9)

# %%
x['k-m label']=kmeans.fit_predict(x)

# %%
x
# Out:
#         company_hash       ctc  years_of_experience  job_position  classs  \
# 0                194  0.330330                  6.0           273       1
# 1               1846  0.135134                  4.0           178       3
# 2                  0  0.600600                  7.0            86       1
# 3               2596  0.210210                  5.0            86       3
# 4               1815  0.420420                  5.0           178       1
# ...              ...       ...                  ...           ...     ...
# 112819           981  0.285285                  3.0            86       3
# 112820          1034  0.300300                  1.0            86       2
# 112821          1442  0.450450                  6.0           178       2
# 112822           117  0.330330                  3.0           128       3
# 112823             0  0.330330                  5.0           176       2
#
#         designation  tier  company_cluster_n  company_job_cluster_n  k-m label
# 0                 2     2                3.0                    3.0          2
# 1                 3     3                3.0                    3.0          0
# 2                 1     1                3.0                    3.0          2
# 3                 3     3                2.0                    2.0          0
# 4                 2     2                3.0                    3.0          0
# ...             ...   ...                ...                    ...        ...
# 112819            3     3                2.0                    2.0          1
# 112820            2     2                3.0                    3.0          1
# 112821            1     1                3.0                    2.0          1
# 112822            1     3                2.0                    2.0          2
# 112823            1     2                3.0                    3.0          2
#
# [112824 rows x 10 columns]

# %%
z=final.copy()
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112824 entries, 0 to 112823
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   company_hash           112824 non-null  object
#  1   orgyear                112824 non-null  float64
#  2   ctc                    112824 non-null  int64
#  3   ctc_updated_year       112824 non-null  float64
#  4   years_of_experience    112824 non-null  float64
#  5   job_position           112824 non-null  object
#  6   classs                 112824 non-null  int64
#  7   designation            112824 non-null  int64
#  8   tier                   112824 non-null  int64
#  9   company_cluster_n      112824 non-null  float64
#  10  company_job_cluster_n  112824 non-null  float64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 10.3+ MB

# %%
#x.drop(columns=['company'],inplace=True)
#x.drop(columns=['ctc'],inplace=True)
#x.drop(columns=['orgyear'],inplace=True)
#x.drop(columns=['job_position'],inplace=True)
#x.drop(columns=['ctc_updated_year'],inplace=True)
#x.info()

# %%
x.info()
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112824 entries, 0 to 112823
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   company_hash           112824 non-null  int64
#  1   ctc                    112824 non-null  float64
#  2   years_of_experience    112824 non-null  float64
#  3   job_position           112824 non-null  int64
#  4   classs                 112824 non-null  int64
#  5   designation            112824 non-null  int64
#  6   tier                   112824 non-null  int64
#  7   company_cluster_n      112824 non-null  float64
#  8   company_job_cluster_n  112824 non-null  float64
#  9   k-m label              112824 non-null  int32
# dtypes: float64(4), int32(1), int64(5)
# memory usage: 9.0 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112824 entries, 0 to 112823
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   company_hash           112824 non-null  object
#  1   orgyear                112824 non-null  float64
#  2   ctc                    112824 non-null  int64
#  3   ctc_updated_year       112824 non-null  float64
#  4   years_of_experience    112824 non-null  float64
#  5   job_position           112824 non-null  object
#  6   classs                 112824 non-null  int64
#  7   designation            112824 non-null  int64
#  8   tier                   112824 non-null  int64
#  9   company_cluster_n      112824 non-null  float64
#  10  company_job_cluster_n  112824 non-null  float64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 10.3+ MB

# %%
#q=pd.merge(x, z, how ='inner', on =['years_of_experience', 'tier','classs','designation'])
#q.info()

# %%
q=pd.concat([z,x['k-m label']], axis=1)
q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112824 entries, 0 to 112823
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   company_hash           112824 non-null  object
#  1   orgyear                112824 non-null  float64
#  2   ctc                    112824 non-null  int64
#  3   ctc_updated_year       112824 non-null  float64
#  4   years_of_experience    112824 non-null  float64
#  5   job_position           112824 non-null  object
#  6   classs                 112824 non-null  int64
#  7   designation            112824 non-null  int64
#  8   tier                   112824 non-null  int64
#  9   company_cluster_n      112824 non-null  float64
#  10  company_job_cluster_n  112824 non-null  float64
#  11  k-m label              112824 non-null  int32
# dtypes: float64(5), int32(1), int64(4), object(2)
# memory usage: 10.8+ MB

# %%
q
# Out:
#                      company_hash  orgyear      ctc  ctc_updated_year  \
# 0                  czniswwz sucsk   2016.0  1100000            2020.0
# 1       oznskulz subilihh nshswzc   2018.0   449999            2019.0
# 2                          Others   2015.0  2000000            2020.0
# 3                       wirijzcsk   2017.0   700000            2019.0
# 4                      osbw toidj   2017.0  1400000            2019.0
# ...                           ...      ...      ...               ...
# 112819                     ioklnz   2019.0   950000            2021.0
# 112820            jinslagkqkkolih   2021.0  1000000            2021.0
# 112821          lft suwzoukwsiukn   2016.0  1500000            2021.0
# 112822                  cduuedhga   2019.0  1100000            2021.0
# 112823                     Others   2017.0  1100000            2021.0
#
#         years_of_experience        job_position  classs  designation  tier  \
# 0                       6.0              others       1            2     2
# 1                       4.0  fullstack devloper       3            3     3
# 2                       7.0    backend engineer       1            1     1
# 3                       5.0    backend engineer       3            3     3
# 4                       5.0  fullstack devloper       1            2     2
# ...                     ...                 ...     ...          ...   ...
# 112819                  3.0    backend engineer       3            3     3
# 112820                  1.0    backend engineer       2            2     2
# 112821                  6.0  fullstack devloper       2            1     1
# 112822                  3.0      data scientist       3            1     3
# 112823                  5.0  frontend developer       2            1     2
#
#         company_cluster_n  company_job_cluster_n  k-m label
# 0                     3.0                    3.0          2
# 1                     3.0                    3.0          0
# 2                     3.0                    3.0          2
# 3                     2.0                    2.0          0
# 4                     3.0                    3.0          0
# ...                   ...                    ...        ...
# 112819                2.0                    2.0          1
# 112820                3.0                    3.0          1
# 112821                3.0                    2.0          1
# 112822                2.0                    2.0          2
# 112823                3.0                    3.0          2
#
# [112824 rows x 12 columns]

# %%
z=x.sample(frac=0.0025)
#the most we could do without crashing

# %%
z=z.drop(columns='k-m label')

# %%
z.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 282 entries, 82496 to 31591
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   company_hash           282 non-null    int64
#  1   ctc                    282 non-null    float64
#  2   years_of_experience    282 non-null    float64
#  3   job_position           282 non-null    int64
#  4   classs                 282 non-null    int64
#  5   designation            282 non-null    int64
#  6   tier                   282 non-null    int64
#  7   company_cluster_n      282 non-null    float64
#  8   company_job_cluster_n  282 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 22.0 KB

# %%
import sys

# %%
sys.setrecursionlimit(100000)

# %%
import scipy.cluster.hierarchy as sch
dendrogrm = sch.dendrogram(sch.linkage(z, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('placements')
plt.ylabel('Euclidean distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
model.fit(z)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
z['Aglo-label'] = model.fit_predict(z)

# %%
z.head()
# Out:
#        company_hash       ctc  years_of_experience  job_position  classs  \
# 82496           340  0.450450                  4.0           331       2
# 59402            84  0.270270                  7.0           176       2
# 7178              0  0.120120                  8.0            86       3
# 68983          2737  0.279279                  3.0           178       3
# 40788          2662  0.570570                  7.0            86       2
#
#        designation  tier  company_cluster_n  company_job_cluster_n  Aglo-label
# 82496            2     2                3.0                    2.0           1
# 59402            2     3                3.0                    3.0           1
# 7178             3     3                3.0                    3.0           1
# 68983            1     3                3.0                    3.0           2
# 40788            2     2                2.0                    2.0           2
